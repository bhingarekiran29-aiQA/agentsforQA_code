# %% [markdown]
# ### LangChain Basics

# %%
# !pip install langchain
# !pip install -U langchain-ollama

# %% [markdown]
# ### Setting up ollama for LangChain with Model qwen-8b

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    base_url="http://localhost:11434",
    model="llama3.2:latest",
    temperature=0.5
)

# %% [markdown]
# #### Call the ollama model

# %%
response = llm.invoke("Hi How are you doing ?")

print(response.content)
# Out:
# I'm doing well, thank you for asking! I'm a large language model, so I don't have emotions or feelings like humans do, but I'm always happy to chat with you and help with any questions or topics you'd like to discuss. How about you? How's your day going so far?

# %% [markdown]
# ### Streaming the response
#
# ```python

# %%
for chuck in llm.stream("Hi How are you doing ?"):
    print(chuck.content, end="", flush=True)
# Out:
# I'm doing well, thank you for asking! I'm a large language model, so I don't have emotions or feelings like humans do, but I'm always happy to chat with you and help with any questions or topics you'd like to discuss. How about you? How's your day going so far?

# %% [markdown]
# #### Understanding Prompt Templates

# %%
from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate.from_template("What is the role of {type} in software Testing")

prompt = prompt_template.invoke({'type': 'Human'})
print(prompt) # -> What is the role of Human in software Testing
# prompt = prompt_template.invoke({}) - we can pass it emty if no parametrization is needed. 

result = llm.invoke(prompt).content

print(result)

# this prompt template is reusable as compared to above in line 6.
# markdownlivepreview.com can be used to view the result in good format.
# Out:
# text='What is the role of Human in software Testing'
# The role of a human in software testing involves a combination of skills, knowledge, and techniques to identify defects, ensure quality, and validate software functionality. Here are some key aspects of the role of humans in software testing:
#
# 1. **Defect Identification**: Humans play a crucial role in identifying defects in software applications. They use various testing techniques, such as exploratory testing, black box testing, and white box testing, to identify defects that may have been overlooked by automated tests.
# 2. **Test Planning**: Human testers work with the development team to plan test cases, identify test scenarios, and prioritize testing activities.
# 3. **Test Case Development**: Humans develop test cases, including input data, expected results, and test scripts, to ensure comprehensive testing of software applications.
# 4. **Test Execution**: Testers execute tests, report defects, and collaborate with the development team to resolve issues.
# 5. **Defect Reporting and Tracking**: Human testers provide detailed defect reports, including steps to reproduce the issue, expected results, and actual results.
# 6. **Test Environment Setup**: Humans set up test environments, including hardware, software, and network configurations, to ensure that tests can be executed successfully.
# 7. **Collaboration with Development Team**: Testers work closely with developers to identify and resolve issues, ensuring that defects are fixed before the software is released to production.
# 8. **Test Automation**: Humans can also contribute to test automation by creating automated tests, identifying areas for automation, and maintaining existing automated tests.
# 9. **Quality Assurance**: Human testers ensure that software applications meet quality standards, including usability, performance, and security requirements.
# 10. **Continuous Learning**: The role of a human in software testing requires continuous learning, as new technologies, methodologies, and tools emerge regularly.
#
# To excel in this role, humans should possess:
#
# 1. Strong analytical and problem-solving skills
# 2. Excellent communication and collaboration skills
# 3. Ability to think critically and creatively
# 4. Knowledge of software testing techniques, methodologies, and tools
# 5. Understanding of quality assurance principles and standards
# 6. Familiarity with agile development methodologies and test-driven development (TDD)
# 7. Willingness to learn and adapt to new technologies and processes
#
# By leveraging the skills and knowledge of humans in software testing, organizations can ensure that their software applications are thoroughly tested, reliable, and meet user expectations.

# %% [markdown]
# #### LangChain Chaining mechanism
#
# ```python

# %%
from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate.from_template("What is the role of {type} in software Testing")

chain = prompt_template | llm  # only combining above code in chain to make it short. 

result = chain.invoke({'type': 'AI'})

print(result.content)
# Out:
# The role of Artificial Intelligence (AI) in software testing has become increasingly significant in recent years. AI-powered tools and techniques are being used to automate various aspects of software testing, making it more efficient, effective, and cost-effective. Here are some key roles of AI in software testing:
#
# 1. **Automated Testing**: AI can automatically generate test cases, execute tests, and report defects, reducing the manual effort required for testing.
# 2. **Test Data Generation**: AI can generate large amounts of realistic test data, reducing the need for human testers to create and maintain test data manually.
# 3. **Bug Detection**: AI-powered tools can analyze code, detect bugs, and provide recommendations for fixing them, improving code quality and reducing defects.
# 4. **Defect Prediction**: AI algorithms can predict which defects are likely to occur in a software application, allowing developers to focus on high-risk areas of the codebase.
# 5. **Test Automation Frameworks**: AI-powered frameworks like Selenium, Appium, and TestComplete provide tools for automating testing, making it easier to write automated tests and reduce manual testing effort.
# 6. **Predictive Analytics**: AI can analyze test data and predict the likelihood of defects, allowing developers to make informed decisions about testing and development priorities.
# 7. **Continuous Integration and Continuous Deployment (CI/CD)**: AI-powered tools can automate CI/CD pipelines, ensuring that software applications are continuously built, tested, and deployed to production environments.
# 8. **Exploratory Testing**: AI can analyze data from exploratory tests, such as user interactions and system logs, to identify areas of the application that require more testing effort.
# 9. **Code Review**: AI-powered tools can review code for quality, security, and compliance with industry standards, reducing the risk of defects and improving overall code quality.
# 10. **Test Environment Management**: AI can manage test environments, including setting up and tearing down test infrastructure, to reduce manual effort and improve testing efficiency.
#
# Benefits of AI in software testing:
#
# 1. **Increased Efficiency**: AI-powered tools automate many tasks, freeing up human testers to focus on higher-value activities like exploratory testing and defect analysis.
# 2. **Improved Accuracy**: AI can detect defects more accurately than humans, reducing the likelihood of false positives and false negatives.
# 3. **Reduced Costs**: AI-powered tools reduce manual effort, enabling organizations to allocate resources more efficiently.
# 4. **Enhanced Quality**: AI-powered tools improve code quality by detecting bugs, predicting defects, and providing recommendations for fixing them.
#
# However, there are also challenges associated with the adoption of AI in software testing, such as:
#
# 1. **Data Quality**: AI algorithms require high-quality data to produce accurate results, which can be a challenge if test data is not well-structured or comprehensive.
# 2. **Explainability**: AI-powered tools may not provide clear explanations for their decisions, making it difficult for developers to understand why certain defects were detected.
# 3. **Bias**: AI algorithms can inherit biases from the data used to train them, which can lead to inaccurate results if the data is biased.
#
# Overall, AI has the potential to revolutionize software testing by increasing efficiency, improving accuracy, and reducing costs. However, it's essential to address the challenges associated with AI adoption to ensure its successful implementation.

# %% [markdown]
# #### Chaining with Parsers

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

prompt_template = PromptTemplate.from_template("What is the role of {type} in software Testing")

chain = prompt_template | llm | StrOutputParser() # this will change the response of LLM to String

result = chain.invoke({'type': 'AI'})

print(result)
# Out:
# The role of Artificial Intelligence (AI) in software testing has become increasingly important in recent years. Here are some ways AI is being used in software testing:
#
# 1. **Automated Testing**: AI-powered tools can automate repetitive and time-consuming testing tasks, such as data entry, test case creation, and test execution.
# 2. **Test Case Generation**: AI algorithms can generate test cases based on the codebase, reducing the manual effort required to create test cases.
# 3. **Test Data Generation**: AI can generate realistic test data, making it easier to test software applications with diverse user inputs.
# 4. **Predictive Analytics**: AI-powered tools can analyze testing data and predict potential issues or defects in the software application.
# 5. **Bug Detection**: AI algorithms can detect bugs and errors in code by analyzing code patterns, syntax, and semantics.
# 6. **Test Automation Frameworks**: AI-powered frameworks can automate test execution, reporting, and analysis, making it easier to manage large-scale testing efforts.
# 7. **Continuous Integration and Continuous Deployment (CI/CD)**: AI can help optimize CI/CD pipelines by automating tests, reducing build times, and improving overall efficiency.
# 8. **Test Environment Management**: AI-powered tools can manage test environments, ensuring that the right hardware and software configurations are used for testing.
# 9. **Defect Prediction**: AI algorithms can predict which defects are likely to occur in a given piece of code, allowing developers to focus on high-risk areas.
# 10. **Code Review**: AI-powered tools can review code changes and suggest improvements, reducing the likelihood of introducing new bugs.
#
# Benefits of using AI in software testing:
#
# 1. **Increased Efficiency**: AI can automate repetitive tasks, freeing up human testers to focus on more complex and creative testing tasks.
# 2. **Improved Accuracy**: AI algorithms can analyze vast amounts of data and detect patterns that may not be apparent to humans.
# 3. **Reduced Costs**: By automating testing tasks, companies can reduce the cost of testing and improve overall ROI.
# 4. **Faster Time-to-Market**: AI-powered testing tools can help developers release software faster, while maintaining quality and reliability.
#
# However, there are also challenges associated with using AI in software testing:
#
# 1. **Data Quality**: The accuracy of AI algorithms depends on the quality of the data used to train them.
# 2. **Bias and Fairness**: AI algorithms can perpetuate biases present in the training data, leading to unfair or discriminatory results.
# 3. **Explainability**: It can be challenging to understand why an AI algorithm made a particular decision or prediction.
# 4. **Security Risks**: AI-powered testing tools may introduce new security risks if not properly secured.
#
# Overall, AI has the potential to revolutionize software testing by increasing efficiency, accuracy, and speed, while reducing costs and improving overall quality.

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import JsonOutputParser

prompt_template = PromptTemplate.from_template("What is the role of {type} in software Testing ? give me the response in JSON format ONLY")

chain = prompt_template | llm | JsonOutputParser() # it will give the response in JSON format, for that prompt need to be updated to ask for the response in JSON format. 

result = chain.invoke({'type': 'AI'})

print(result)
# Out:
# {'role_of_AI_in_software_testing': 'AI plays a significant role in software testing by automating test case generation, execution, and analysis. It helps in identifying bugs more efficiently, reducing human effort, and increasing the coverage of tests. AI can also predict potential issues based on historical data and improve overall quality assurance processes.'}

# %%
from langchain_core.output_parsers import StrOutputParser
 
parser = StrOutputParser()
parser.invoke("Thought: I need to multiply two numbers\nAction: Multiply\nInput: 4 and 5\nFinal Answer: 20")
# Out:
# 'Thought: I need to multiply two numbers\nAction: Multiply\nInput: 4 and 5\nFinal Answer: 20'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
